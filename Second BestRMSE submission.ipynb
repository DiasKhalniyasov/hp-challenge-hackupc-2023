# %%
pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.20.0 typeguard-2.13.3

# %% [markdown]
# ### Here we used NN with 1 hidden layer and our Future Forecast method

# %%
import pandas as pd
import numpy as np
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt
from keras.models import Sequential
import tensorflow as tf
from keras.layers import Dense, LSTM
import tensorflow_addons as tfa
import os
import tensorflow as tf
from tensorflow.keras import layers
# %matplotlib inline
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# ### Read Dataset

# %%
data = pd.read_csv('/content/train.csv')
data
# Out:
#                   id        date  year_week  product_number  reporterhq_id  \
# 0        202119-6909  2021-05-15     202119            6909             93
# 1        202120-6909  2021-05-22     202120            6909             93
# 2        202121-6909  2021-05-29     202121            6909             93
# 3        202122-6909  2021-06-05     202122            6909             93
# 4        202123-6909  2021-06-12     202123            6909             93
# ...              ...         ...        ...             ...            ...
# 15449  202317-247737  2023-04-29     202317          247737             15
# 15450  202317-247737  2023-04-29     202317          247737             24
# 15451  202318-247737  2023-05-06     202318          247737              3
# 15452  202318-247737  2023-05-06     202318          247737             15
# 15453  202318-247737  2023-05-06     202318          247737             24
#
#       prod_category  specs  display_size  segment  sales_units  \
# 0             Arale  21274          13.3  Premium          2.0
# 1             Arale  21274          13.3  Premium          0.0
# 2             Arale  21274          13.3  Premium          3.0
# 3             Arale  21274          13.3  Premium          0.0
# 4             Arale  21274          13.3  Premium          0.0
# ...             ...    ...           ...      ...          ...
# 15449         Arale  10637          13.3  Premium          0.0
# 15450         Arale  10637          13.3  Premium          0.0
# 15451         Arale  10637          13.3  Premium         22.0
# 15452         Arale  10637          13.3  Premium         68.0
# 15453         Arale  10637          13.3  Premium          5.0
#
#        inventory_units
# 0                 35.0
# 1                 70.0
# 2                137.0
# 3                274.0
# 4                333.0
# ...                ...
# 15449             62.0
# 15450              3.0
# 15451              0.0
# 15452             78.0
# 15453              1.0
#
# [15454 rows x 11 columns]

# %% [markdown]
# # Data Processing

# %% [markdown]
# Cast column types

# %%
# Define the column type mapping
cate_columns = ['id', 'year_week', 'product_number', 'reporterhq_id',
       'prod_category', 'specs', 'display_size', 'segment']
data[cate_columns] = data[cate_columns].astype('str')
data['date'] = pd.to_datetime(data['date'])

# %%
dfs = []
config = {
    "236880":"202201",
    "148050":"202243",
    "12831":"202221",
    "48363":"202233",
    "157920":"202228",
    "190491":"202227",
    "46389":"202204",
    "116466":"202217",
    "234906":"202204"
}
product_ids = data.product_number.unique()
for product_id in product_ids:
  if product_id in list(config.keys()):
    abc = data[(data['product_number'] == product_id) & (data['year_week'] >= config[product_id]) & (data['year_week'] <= '202318')]
    dfs.append(abc)
  dfs.append(data[data['product_number'] == product_id])
df_col_merged = pd.concat(dfs, axis=0)
df_col_merged.head(2)
# Out:
#             id       date year_week product_number reporterhq_id  \
# 0  202119-6909 2021-05-15    202119           6909            93
# 1  202120-6909 2021-05-22    202120           6909            93
#
#   prod_category  specs display_size  segment  sales_units  inventory_units
# 0         Arale  21274         13.3  Premium          2.0             35.0
# 1         Arale  21274         13.3  Premium          0.0             70.0

# %%
def generate_year_week_list(start_year, start_week, end_year=2023, end_week=18):
    start_date = datetime.datetime.strptime(f'{start_year}-W{start_week}-1', '%Y-W%W-%w')
    end_date = datetime.datetime.strptime(f'{end_year}-W{end_week}-1', '%Y-W%W-%w')
    current_date = start_date
    year_week_list = []
    
    while current_date <= end_date:
        year = current_date.isocalendar()[0]
        week = current_date.isocalendar()[1]
        year_week_list.append((year, f'{week:02}'))  # Format week number with leading zeros
        current_date += datetime.timedelta(weeks=1)

    df = pd.DataFrame(year_week_list, columns=['Year', 'Week'])
  
    return df

# %%
import datetime
df_col_mergedd = df_col_merged.groupby(['date', 'year_week', 'product_number', 'prod_category', 'display_size', 'segment']).agg({'sales_units': 'sum', 'inventory_units':'sum'}).reset_index()

dfs = []
for product_id in df_col_mergedd.product_number.unique():
    da = df_col_mergedd[df_col_mergedd['product_number']==product_id]

    da = da.sort_values("year_week", ascending=True)
    year_week = da.head(1)['year_week'].values[0]

    start_year = year_week[:4]
    start_week = year_week[-2:]

    ab = generate_year_week_list(int(start_year),int(start_week))
    ab["year_week"] = ab["Year"].astype(str) + ab['Week'].astype(str)
    
    abc = ab.merge(da, on='year_week', how='left')
    dfs.append(abc)

df_col = pd.concat(dfs, axis=0)
df_col.fillna(method='ffill', inplace = True)

# %%
# Out:
#     Year Week year_week       date product_number prod_category display_size  \
# 0   2019   16    201916 2019-04-20         233919        Clover         15.6
# 1   2019   17    201917 2019-04-27         233919        Clover         15.6
# 2   2019   18    201918 2019-05-04         233919        Clover         15.6
# 3   2019   19    201919 2019-05-11         233919        Clover         15.6
# 4   2019   20    201920 2019-05-18         233919        Clover         15.6
# ..   ...  ...       ...        ...            ...           ...          ...
# 27  2023   14    202314 2023-04-08         107583        Clover         15.6
# 28  2023   15    202315 2023-04-15         107583        Clover         15.6
# 29  2023   16    202316 2023-04-22         107583        Clover         15.6
# 30  2023   17    202317 2023-04-29         107583        Clover         15.6
# 31  2023   18    202318 2023-05-06         107583        Clover         15.6
#
#    segment  sales_units  inventory_units
# 0     Core          3.0             43.0
# 1     Core        122.0            184.0
# 2     Core         61.0            219.0
# 3     Core         33.0            133.0
# 4     Core        142.0            310.0
# ..     ...          ...              ...
# 27    Core         16.0            504.0
# 28    Core         77.0            245.0
# 29    Core        136.0            443.0
# 30    Core        115.0            297.0
# 31    Core         67.0            242.0
#
# [8053 rows x 10 columns]

# %%
def fix_date(data):
  sample = data.sort_values('year_week',ascending=True).reset_index(drop=True)
  for i in range(len(sample)-1):
    sample['date'][i+1] = sample['date'][i] + datetime.timedelta(weeks = 1)
  return sample

# %%
df_col['date'] = pd.to_datetime(df_col['date'])
dfs = []
for product_id in df_col.product_number.unique():
    da = df_col[df_col['product_number']==product_id]
    ab = fix_date(da)
    dfs.append(ab)
df_col = pd.concat(dfs, axis=0)
df_col.head(2)
# Out:
# <ipython-input-15-1939b2ea315a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['date'][i+1] = sample['date'][i] + datetime.timedelta(weeks = 1)
#    Year Week year_week       date product_number prod_category display_size  \
# 0  2019   16    201916 2019-04-20         233919        Clover         15.6
# 1  2019   17    201917 2019-04-27         233919        Clover         15.6
#
#   segment  sales_units  inventory_units
# 0    Core          3.0             43.0
# 1    Core        122.0            184.0

# %%
df_col.to_csv('final_data.csv',index=False)

# %% [markdown]
# ### Future Forecast method

# %%
inventory_data = pd.read_csv('/content/final_data.csv', parse_dates=["date"], index_col=["date"]).sort_index()
cate_columns = ['year_week', 'product_number', 'Year', 'Week',
       'prod_category', 'display_size', 'segment']
inventory_data[cate_columns] = inventory_data[cate_columns].astype('str')

# %%
# Generate new columns and get their mean and std values

WINDOW_SIZE=4
list_data = []
for product_id in inventory_data.product_number.unique():
    da = df_col[df_col['product_number']==product_id]

    for i in range(WINDOW_SIZE): # Shift values for each step in WINDOW_SIZE
        da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
    da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
    da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
    list_data.append(da)

clean_data = pd.concat(list_data, axis=0)
clean_data.head(2)
# Out:
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da[f"inventory_units+{i+1}"] = da["inventory_units"].shift(periods=i+1)
# <ipython-input-27-80124b0c5bd6>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['Mean'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
# <ipython-input-27-80124b0c5bd6>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   da['std'] = da[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
#    Year Week year_week       date product_number prod_category display_size  \
# 0  2019   16    201916 2019-04-20         233919        Clover         15.6
# 1  2019   17    201917 2019-04-27         233919        Clover         15.6
#
#   segment  sales_units  inventory_units  inventory_units+1  inventory_units+2  \
# 0    Core          3.0             43.0                NaN                NaN
# 1    Core        122.0            184.0               43.0                NaN
#
#    inventory_units+3  inventory_units+4  Mean  std
# 0                NaN                NaN   NaN  NaN
# 1                NaN                NaN  43.0  NaN

# %%
# Prepare data for training
def prepare_df(df):
    df = df[['product_number', 'prod_category','display_size', 'segment', 'sales_units', "inventory_units+1", "inventory_units+2", "inventory_units+3", "inventory_units+4", "Mean", "std"]]
    df = pd.get_dummies(df, columns=['product_number', 'prod_category','display_size', 'segment'])
    return df
X_all = clean_data.drop(["inventory_units"], axis=1).dropna()
X_train = prepare_df(X_all)
y_train = clean_data.dropna()["inventory_units"]

# %%
# Find bes parameters for training

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
rf = RandomForestRegressor(random_state = 42)
n_estimators = [100, 200, 400, 600] # number of trees in the random forest
max_depth = [5, 10, 15, 20] # maximum number of levels allowed in each decision tree

random_grid = {'n_estimators': n_estimators,

'max_depth': max_depth,
}

rf_random = RandomizedSearchCV(estimator = rf,param_distributions = random_grid, n_iter = 100, cv = 5, verbose=2, random_state=42, n_jobs = -1)
rf_random.fit(X_train,y_train)

# %%
model_1 = rf_random.best_estimator_
# Set random seed for as reproducible results as possible
tf.random.set_seed(42)

# Construct model
model_1 = tf.keras.Sequential([
    layers.Dense(64, activation='relu'),
    layers.Dense(1)      
], name="model_1_dense") # give the model a name so we can save it

# Compile model
model_1.compile(
                optimizer=tf.keras.optimizers.Adam(lr=0.001),
                loss='mse',
                metrics=[tf.keras.metrics.RootMeanSquaredError()]) 

model_1.fit(x=X_train, # train windows of 4 timesteps of maize prices
            y=y_train, # horizon value of 1
            epochs=100,
            verbose=1,
            batch_size=32,) # create ModelCheckpoint callback to save best model
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 240/240 [==============================] - 2s 3ms/step - loss: 10728.5215 - root_mean_squared_error: 103.5786
# Epoch 2/100
# 240/240 [==============================] - 1s 3ms/step - loss: 5056.6230 - root_mean_squared_error: 71.1099
# Epoch 3/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4918.0215 - root_mean_squared_error: 70.1286
# Epoch 4/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4776.1162 - root_mean_squared_error: 69.1095
# Epoch 5/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4733.2075 - root_mean_squared_error: 68.7983
# Epoch 6/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4716.4062 - root_mean_squared_error: 68.6761
# Epoch 7/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4717.9966 - root_mean_squared_error: 68.6877
# Epoch 8/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4700.4180 - root_mean_squared_error: 68.5596
# Epoch 9/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4687.8130 - root_mean_squared_error: 68.4676
# Epoch 10/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4709.5430 - root_mean_squared_error: 68.6261
# Epoch 11/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4756.9507 - root_mean_squared_error: 68.9706
# Epoch 12/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4703.1665 - root_mean_squared_error: 68.5796
# Epoch 13/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4681.2271 - root_mean_squared_error: 68.4195
# Epoch 14/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4676.0093 - root_mean_squared_error: 68.3813
# Epoch 15/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4600.3740 - root_mean_squared_error: 67.8261
# Epoch 16/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4595.2686 - root_mean_squared_error: 67.7884
# Epoch 17/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4744.5107 - root_mean_squared_error: 68.8804
# Epoch 18/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4606.5571 - root_mean_squared_error: 67.8716
# Epoch 19/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4579.3662 - root_mean_squared_error: 67.6710
# Epoch 20/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4667.0161 - root_mean_squared_error: 68.3156
# Epoch 21/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4588.0269 - root_mean_squared_error: 67.7350
# Epoch 22/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4595.2798 - root_mean_squared_error: 67.7885
# Epoch 23/100
# 240/240 [==============================] - 2s 7ms/step - loss: 4566.3501 - root_mean_squared_error: 67.5748
# Epoch 24/100
# 240/240 [==============================] - 1s 6ms/step - loss: 4587.5234 - root_mean_squared_error: 67.7313
# Epoch 25/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4545.5820 - root_mean_squared_error: 67.4209
# Epoch 26/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4566.1069 - root_mean_squared_error: 67.5730
# Epoch 27/100
# 240/240 [==============================] - 1s 5ms/step - loss: 4582.1958 - root_mean_squared_error: 67.6919
# Epoch 28/100
# 240/240 [==============================] - 1s 6ms/step - loss: 4538.3076 - root_mean_squared_error: 67.3670
# Epoch 29/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4561.6089 - root_mean_squared_error: 67.5397
# Epoch 30/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4518.2910 - root_mean_squared_error: 67.2182
# Epoch 31/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4531.9351 - root_mean_squared_error: 67.3196
# Epoch 32/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4580.7124 - root_mean_squared_error: 67.6810
# Epoch 33/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4526.7251 - root_mean_squared_error: 67.2809
# Epoch 34/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4506.4805 - root_mean_squared_error: 67.1303
# Epoch 35/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4496.8154 - root_mean_squared_error: 67.0583
# Epoch 36/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4465.4058 - root_mean_squared_error: 66.8237
# Epoch 37/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4594.9072 - root_mean_squared_error: 67.7857
# Epoch 38/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4511.3066 - root_mean_squared_error: 67.1663
# Epoch 39/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4512.6162 - root_mean_squared_error: 67.1760
# Epoch 40/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4549.2832 - root_mean_squared_error: 67.4484
# Epoch 41/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4576.4541 - root_mean_squared_error: 67.6495
# Epoch 42/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4488.7817 - root_mean_squared_error: 66.9984
# Epoch 43/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4577.2202 - root_mean_squared_error: 67.6552
# Epoch 44/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4524.8745 - root_mean_squared_error: 67.2672
# Epoch 45/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4481.9644 - root_mean_squared_error: 66.9475
# Epoch 46/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4436.8394 - root_mean_squared_error: 66.6096
# Epoch 47/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4484.4790 - root_mean_squared_error: 66.9662
# Epoch 48/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4451.6084 - root_mean_squared_error: 66.7204
# Epoch 49/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4514.5210 - root_mean_squared_error: 67.1902
# Epoch 50/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4458.8203 - root_mean_squared_error: 66.7744
# Epoch 51/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4516.5996 - root_mean_squared_error: 67.2057
# Epoch 52/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4464.8789 - root_mean_squared_error: 66.8197
# Epoch 53/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4417.7427 - root_mean_squared_error: 66.4661
# Epoch 54/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4431.3169 - root_mean_squared_error: 66.5681
# Epoch 55/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4439.1572 - root_mean_squared_error: 66.6270
# Epoch 56/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4454.6152 - root_mean_squared_error: 66.7429
# Epoch 57/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4438.4692 - root_mean_squared_error: 66.6218
# Epoch 58/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4425.4155 - root_mean_squared_error: 66.5238
# Epoch 59/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4387.7993 - root_mean_squared_error: 66.2405
# Epoch 60/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4527.4199 - root_mean_squared_error: 67.2861
# Epoch 61/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4408.8428 - root_mean_squared_error: 66.3991
# Epoch 62/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4414.2275 - root_mean_squared_error: 66.4397
# Epoch 63/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4412.4722 - root_mean_squared_error: 66.4264
# Epoch 64/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4417.5381 - root_mean_squared_error: 66.4646
# Epoch 65/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4396.4673 - root_mean_squared_error: 66.3059
# Epoch 66/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4439.0435 - root_mean_squared_error: 66.6261
# Epoch 67/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4385.3716 - root_mean_squared_error: 66.2221
# Epoch 68/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4389.7690 - root_mean_squared_error: 66.2553
# Epoch 69/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4367.9375 - root_mean_squared_error: 66.0904
# Epoch 70/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4405.5552 - root_mean_squared_error: 66.3744
# Epoch 71/100
# 240/240 [==============================] - 1s 6ms/step - loss: 4408.8740 - root_mean_squared_error: 66.3994
# Epoch 72/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4444.9595 - root_mean_squared_error: 66.6705
# Epoch 73/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4362.2632 - root_mean_squared_error: 66.0474
# Epoch 74/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4352.8901 - root_mean_squared_error: 65.9764
# Epoch 75/100
# 240/240 [==============================] - 1s 5ms/step - loss: 4342.1670 - root_mean_squared_error: 65.8951
# Epoch 76/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4374.2139 - root_mean_squared_error: 66.1378
# Epoch 77/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4360.3955 - root_mean_squared_error: 66.0333
# Epoch 78/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4369.9453 - root_mean_squared_error: 66.1056
# Epoch 79/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4347.5474 - root_mean_squared_error: 65.9359
# Epoch 80/100
# 240/240 [==============================] - 1s 5ms/step - loss: 4343.8643 - root_mean_squared_error: 65.9080
# Epoch 81/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4343.9722 - root_mean_squared_error: 65.9088
# Epoch 82/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4355.9619 - root_mean_squared_error: 65.9997
# Epoch 83/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4312.8628 - root_mean_squared_error: 65.6724
# Epoch 84/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4341.2856 - root_mean_squared_error: 65.8884
# Epoch 85/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4374.0654 - root_mean_squared_error: 66.1367
# Epoch 86/100
# 240/240 [==============================] - 1s 4ms/step - loss: 4348.3550 - root_mean_squared_error: 65.9421
# Epoch 87/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4323.3423 - root_mean_squared_error: 65.7521
# Epoch 88/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4277.2773 - root_mean_squared_error: 65.4009
# Epoch 89/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4312.4604 - root_mean_squared_error: 65.6693
# Epoch 90/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4258.8081 - root_mean_squared_error: 65.2595
# Epoch 91/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4246.3604 - root_mean_squared_error: 65.1641
# Epoch 92/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4288.3936 - root_mean_squared_error: 65.4858
# Epoch 93/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4277.7534 - root_mean_squared_error: 65.4045
# Epoch 94/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4257.3003 - root_mean_squared_error: 65.2480
# Epoch 95/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4268.0815 - root_mean_squared_error: 65.3306
# Epoch 96/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4310.1670 - root_mean_squared_error: 65.6519
# Epoch 97/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4277.7241 - root_mean_squared_error: 65.4043
# Epoch 98/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4230.8213 - root_mean_squared_error: 65.0448
# Epoch 99/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4262.1582 - root_mean_squared_error: 65.2852
# Epoch 100/100
# 240/240 [==============================] - 1s 3ms/step - loss: 4229.9399 - root_mean_squared_error: 65.0380

# %%
model_1.evaluate(X_train, y_train)
# Out:
# 240/240 [==============================] - 1s 3ms/step - loss: 4192.0083 - root_mean_squared_error: 64.7457
# [4192.00830078125, 64.74571990966797]

# %% [markdown]
# ### Inference

# %%
# we need to prepare the test data 
# and fill empty values before we can submit it
test_df = pd.read_csv('test.csv')
test_df[['year_week', 'product_number']] = test_df.id.str.split('-', expand = True)
test_df['product_number'] = test_df.product_number
test_df
# Out:
#                  id year_week product_number
# 0     202319-105609    202319         105609
# 1     202319-107583    202319         107583
# 2      202319-10857    202319          10857
# 3     202319-109557    202319         109557
# 4     202319-112518    202319         112518
# ...             ...       ...            ...
# 1295   202331-92778    202331          92778
# 1296   202331-93765    202331          93765
# 1297   202331-94752    202331          94752
# 1298    202331-9870    202331           9870
# 1299   202331-99687    202331          99687
#
# [1300 rows x 3 columns]

# %%
# each product has specific information, we are just creating a reference table
product_mapping = X_all[['product_number', 'prod_category','display_size', 'segment']].drop_duplicates()
test_df_complete = test_df.merge(product_mapping, on='product_number', how = 'left')

# %%
# Use average mean, std from predicted + last 3 predicted values 

results = {}
for product_id in test_df_complete.product_number.unique():
    feature_values = []
    future_forecast = []
    da = test_df_complete[test_df_complete['product_number']==product_id]
    last_window = list(clean_data[clean_data['product_number']==product_id].inventory_units.values[-WINDOW_SIZE:])
    last_sales = list(clean_data[clean_data['product_number']==product_id].sales_units.values[-WINDOW_SIZE:])
    for i in range(13):
        features = da[['product_number', 'prod_category','display_size', 'segment']].head(1)
        features["inventory_units+1"] = last_window[3]
        features["inventory_units+2"] = last_window[2]
        features["inventory_units+3"] = last_window[1]
        features["inventory_units+4"] = last_window[0]
        features['Mean'] = features[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].mean(axis=1)
        features['std'] = features[['inventory_units+1', 'inventory_units+2', 'inventory_units+3', 'inventory_units+4']].std(axis=1)
        mean = np.mean(last_sales)
        features['sales_units'] = [mean]
        last_sales = (last_sales + [mean])[1:]
        prepare_feature = prepare_df(features)
        # Align columns of test set with training set
        missing_cols = set(X_train.columns) - set(prepare_feature.columns)
        for col in missing_cols:
            prepare_feature[col] = 0

        prepare_feature = prepare_feature[X_train.columns]
        pred_value = model_1.predict(prepare_feature)
        # Create an empty list for future forcast
        last_window = (list(pred_value[0]) + last_window)[:-1]
        future_forecast.append(pred_value[0][0])

        # Create a empty list for future feature
        feature_values.append(last_window)
    
    results[product_id] = future_forecast

# %%
results
# Out:
# {'105609': [87.08889,
#   109.37649,
#   53.49177,
#   68.80196,
#   88.677025,
#   111.033295,
#   67.37909,
#   68.19325,
#   87.2289,
#   113.59592,
#   79.00581,
#   68.86702,
#   84.23772],
#  '107583': [231.94926,
#   260.73267,
#   368.77362,
#   242.2068,
#   210.23448,
#   223.19405,
#   324.69812,
#   239.54391,
#   193.24358,
#   190.78719,
#   285.36847,
#   238.4991,
#   180.5018],
#  '10857': [207.55919,
#   147.75772,
#   148.87346,
#   228.18762,
#   197.39201,
#   132.57375,
#   133.2792,
#   207.50633,
#   187.84323,
#   118.991615,
#   118.17865,
#   188.0495,
#   178.6353],
#  '109557': [83.19767,
#   80.664116,
#   107.11786,
#   117.83331,
#   81.00839,
#   72.57898,
#   90.893906,
#   110.440285,
#   81.31434,
#   68.014786,
#   78.351906,
#   102.11217,
#   82.80501],
#  '112518': [178.57259,
#   168.34315,
#   185.9356,
#   200.50267,
#   174.29713,
#   160.76341,
#   171.36238,
#   189.44688,
#   171.34349,
#   156.25192,
#   160.42368,
#   179.00172,
#   168.65898],
#  '114492': [188.81572,
#   152.81006,
#   181.92235,
#   247.92728,
#   174.26651,
#   134.77684,
#   150.72203,
#   216.9893,
#   164.5105,
#   118.77981,
#   123.81395,
#   185.45238,
#   157.4211],
#  '116466': [199.65282,
#   177.19278,
#   159.53249,
#   161.1496,
#   180.19136,
#   168.28204,
#   152.26015,
#   148.12517,
#   163.74437,
#   159.47643,
#   146.66112,
#   139.48027,
#   150.50928],
#  '11844': [261.44333,
#   232.47527,
#   133.7435,
#   165.26595,
#   236.51808,
#   206.6816,
#   128.80214,
#   144.45259,
#   213.93999,
#   188.80737,
#   121.74581,
#   127.55167,
#   194.76604],
#  '119427': [285.67142,
#   247.83827,
#   280.45523,
#   303.5138,
#   252.54936,
#   223.4538,
#   256.6319,
#   280.75818,
#   224.88768,
#   203.16536,
#   234.68297,
#   259.99512,
#   201.7387],
#  '127323': [127.14245,
#   105.5607,
#   134.90282,
#   175.75328,
#   130.87303,
#   105.82546,
#   124.19229,
#   166.22116,
#   134.61821,
#   103.03058,
#   114.88031,
#   155.71764,
#   138.17693],
#  '12831': [305.12836,
#   242.933,
#   145.2495,
#   203.10216,
#   275.5746,
#   226.13573,
#   144.39583,
#   168.00479,
#   243.83208,
#   217.13599,
#   143.73901,
#   142.95958,
#   210.41243],
#  '129297': [53.831814,
#   36.11986,
#   16.071487,
#   39.295895,
#   70.67993,
#   55.914974,
#   29.103104,
#   39.01563,
#   83.85237,
#   75.90513,
#   41.19371,
#   47.81289,
#   95.155815],
#  '130284': [213.64973,
#   187.07271,
#   180.72801,
#   192.61244,
#   196.51848,
#   169.00255,
#   165.46165,
#   178.66032,
#   181.26512,
#   153.73936,
#   304.75763,
#   299.056,
#   310.98276,
#   240.09093,
#   260.50116,
#   263.44098,
#   276.23276,
#   224.48534,
#   230.80836,
#   234.60963,
#   250.25078,
#   212.7282],
#  '46389': [354.9453,
#   340.83252,
#   337.78293,
#   488.68906,
#   345.78485,
#   303.36533,
#   285.22034,
#   420.50626,
#   337.18576,
#   271.97205,
#   246.16022,
#   359.07523,
#   326.44202],
#  '48363': [944.26056,
#   1069.5938,
#   970.70795,
#   908.02264,
#   812.43896,
#   918.7404,
#   837.6021,
#   763.95856,
#   691.90106,
#   779.2586,
#   716.0004,
#   636.59534,
#   579.2186],
#  '51324': [115.17937,
#   125.90176,
#   124.1014,
#   98.78372,
#   102.67045,
#   113.3772,
#   113.03284,
#   88.6379,
#   90.972885,
#   101.23125,
#   103.27464,
#   80.15656,
#   80.434296],
#  '57246': [59.934914,
#   50.871098,
#   31.50377,
#   29.184853,
#   66.843445,
#   66.66256,
#   37.956615,
#   33.08346,
#   72.99109,
#   78.81398,
#   44.272514,
#   37.221924,
#   78.129715],
#  '58233': [437.6292,
#   612.3604,
#   599.1811,
#   474.91788,
#   417.3952,
#   557.2105,
#   567.40234,
#   414.48804,
#   394.12,
#   508.50964,
#   522.89154,
#   368.72717,
#   368.57452],
#  '59220': [130.93289,
#   153.98344,
#   146.17651,
#   185.86461,
#   127.704346,
#   145.913,
#   144.88991,
#   170.90517,
#   121.585464,
#   137.57152,
#   141.63843,
#   158.93712,
#   114.19716],
#  '62181': [138.79018,
#   216.55867,
#   291.0602,
#   288.67926,
#   143.61377,
#   182.61052,
#   257.67804,
#   253.95706,
#   139.8437,
#   153.39008,
#   223.93886,
#   228.84532,
#   136.4915],
#  '64155': [267.59058,
#   186.90935,
#   156.25748,
#   206.37135,
#   247.16243,
#   173.81757,
#   141.84203,
#   168.54178,
#   223.22037,
#   168.20712,
#   132.07362,
#   141.71645,
#   196.71872],
#  '65142': [135.72028,
#   176.91644,
#   178.28954,
#   146.71277,
#   121.198715,
#   145.32571,
#   157.13142,
#   131.78336,
#   111.35309,
#   122.92001,
#   138.40366,
#   121.891106,
#   104.53189],
#  '6909': [87.06585,
#   80.0234,
#   98.025314,
#   137.9277,
#   86.18135,
#   71.982956,
#   81.938644,
#   120.175064,
#   85.11336,
#   66.0343,
#   68.15038,
#   105.47957,
#   84.97519],
#  '73038': [28.013845,
#   55.356693,
#   75.27211,
#   79.26597,
#   37.170326,
#   59.460743,
#   77.60076,
#   85.09601,
#   44.343548,
#   59.912777,
#   78.29697,
#   90.00368,
#   50.76958],
#  '75012': [383.13446,
#   451.55292,
#   483.97137,
#   407.54245,
#   348.58844,
#   410.0407,
#   449.4538,
#   365.14865,
#   318.36148,
#   372.1408,
#   416.59695,
#   330.3939,
#   291.2746],
#  '77973': [57.489506,
#   58.43446,
#   59.529343,
#   85.39729,
#   64.327515,
#   60.764442,
#   65.38678,
#   89.26754,
#   70.53647,
#   62.47244,
#   70.31021,
#   92.94992,
#   76.10949],
#  '7896': [128.17882,
#   187.70007,
#   226.12462,
#   184.9348,
#   111.74295,
#   150.08446,
#   195.15558,
#   158.64595,
#   99.44519,
#   117.980896,
#   167.6609,
#   142.21883,
#   90.90674],
#  '80934': [146.83559,
#   140.8897,
#   91.39603,
#   96.132645,
#   130.58589,
#   135.48708,
#   98.18175,
#   92.92293,
#   116.30849,
#   130.51344,
#   102.8288,
#   92.38656,
#   105.229095],
#  '81921': [187.22731,
#   171.34935,
#   129.61589,
#   137.30019,
#   162.97423,
#   159.09795,
#   126.510544,
#   123.21614,
#   142.70375,
#   148.45967,
#   123.908,
#   114.80035,
#   126.936005],
#  '82908': [213.23167,
#   179.00865,
#   220.07948,
#   183.06715,
#   197.18483,
#   173.12202,
#   205.93532,
#   175.65637,
#   182.5489,
#   165.60454,
#   192.27641,
#   166.48227,
#   168.6668],
#  '83895': [148.19298,
#   175.04497,
#   125.51982,
#   137.94392,
#   146.09218,
#   166.92561,
#   121.92942,
#   132.80028,
#   143.48453,
#   160.05983,
#   117.77117,
#   128.0873,
#   140.61195],
#  '86856': [37.820976,
#   58.354797,
#   119.73302,
#   152.81454,
#   44.655094,
#   64.0789,
#   120.0961,
#   132.31552,
#   46.714935,
#   57.91886,
#   115.93135,
#   122.47591,
#   48.983463],
#  '87843': [117.997894,
#   95.679016,
#   95.20082,
#   81.64894,
#   99.371574,
#   84.32323,
#   88.9224,
#   70.22713,
#   81.12512,
#   66.12537,
#   75.04148,
#   56.462074,
#   65.03068],
#  '8883': [161.30489,
#   175.45857,
#   163.33922,
#   140.40677,
#   148.59785,
#   164.19176,
#   149.6899,
#   126.72398,
#   137.87111,
#   154.51381,
#   138.15044,
#   114.98146,
#   128.27693],
#  '89817': [73.15074,
#   112.51659,
#   139.67845,
#   143.41759,
#   71.054504,
#   107.338455,
#   136.99026,
#   135.80513,
#   69.22044,
#   102.23325,
#   133.85905,
#   130.69276,
#   67.76806],
#  '91791': [153.94675,
#   187.44102,
#   169.98483,
#   127.20767,
#   144.76225,
#   177.68437,
#   157.49997,
#   116.91302,
#   135.87486,
#   168.72466,
#   146.28929,
#   108.17326,
#   127.49777],
#  '92778': [81.74487,
#   104.452156,
#   68.72195,
#   59.55975,
#   72.196815,
#   103.47716,
#   75.55944,
#   58.802322,
#   64.06764,
#   98.664764,
#   83.379425,
#   60.048615,
#   58.505848],
#  '93765': [44.92991,
#   62.676914,
#   64.73074,
#   95.852036,
#   58.891525,
#   68.81832,
#   69.50438,
#   93.5002,
#   70.833496,
#   72.59817,
#   71.77388,
#   91.64705,
#   78.43545],
#  '94752': [349.19598,
#   289.49905,
#   170.39322,
#   232.5559,
#   312.75772,
#   258.9782,
#   164.19998,
#   216.66089,
#   284.3296,
#   232.47362,
#   155.85008,
#   200.28981,
#   260.69455],
#  '9870': [113.47432,
#   87.10751,
#   78.49877,
#   121.59327,
#   113.13895,
#   83.4767,
#   68.947075,
#   100.58561,
#   109.607254,
#   83.35342,
#   65.3695,
#   82.9019,
#   101.21063],
#  '99687': [208.2942,
#   180.228,
#   259.88004,
#   293.1299,
#   191.28174,
#   177.32048,
#   239.49785,
#   270.56363,
#   179.54866,
#   170.90617,
#   220.02199,
#   250.46407,
#   168.88576]}

# %%
import json
with open("result_final.json", "w") as fp:
    json.dump(results,fp)
